# %%
key_list3_general = ["와이파이명", "1층", "2층", "3층", "4층", "(WI-FI)", "패스워드", "WIFI", "ID", "PW", "1·2층", 
"FREE", "WI-FI", "네트워크:", "패스워드:", "WIFI", "PW:", "WI-FI:", "PW:", "ZONE", "무선",
"인터넷", "WITI", "AP:", "PASSWORD", "와이파이", "비밀번호", "ID:", "WIF", "PASSWOR", "PA",
"SSWORD", "아이디", "비번", "DW", "**", "WF", "WITI", "WI", "★PASSWORD", "★PASSWORD★",
"WI-FI", "WIFI", "I-FI", "PASSWO", "WIFI(와이", "WIFI(와이파이)", "PASSWORE", "네트워크", "WI", "PW)",
"WI-FIZONE", "SSID", "W:", "D:", "PASS:", "1F", "2F", "3F", "4F", "SSID",
"검색명칭", "패스워트", "P/W", "WI-FI(ID)", "I'D:", "PN:", "P.W", "WI-", "WI-FIZONE", "무선랜",
"5G전용", "POSSWORD", "POSS", "WORD", "무선랜명:", "FI", "KEY", "계정", "WIFT", "WTFI",
"WTFT", "P.W.:", "ID:", "PASS:", "FW", "IP", "와이", "파이", "이파이", "와이파",
"ID_", "PW_", "PIN", "P/W", "WI-F", "I_", "FI_", "IFI_", "NAME", "PASS", "WORD", "WIFIID", "NETWORK"]

key_list3_receipt = ["[WIF", "PASSWORD]", "SWORD]", "PAS", "WIFI아이디는", "비밀번호는", "무선인터넷은",
"무선인터넷", "WIFI아이디", "WIFI비밀번호", "WI", "-FI", "WI-", "PW-", "WIP", "WIPI",
"W:", "IF", "와이파이P/W", "P/Ø", "|비밀번호", "FI비밀번호", "IFI비밀번호", "W1TI", "W1T1", "WIT1",
"W1", "T1", "Wㅣ", "Fㅣ", "PASSWARD", "ACCESS", "CODE", "I-FI:", "-FI:", "FI:", "PASS", "PASS:",
"1D", "이름", "WIFIPASSWORD", "[와이파", "OI] ", "[와이파이]", "I아이디", "PIII", "1/D", "무선", "무선랜", "P.W",
"P.\\", "IFI", "\\IFI", "FI비밀번호", "WI-F1", "W1F1", "ID-", "PW-", "B1층", "1층,2층", "P.", "<WI-FI>", "ID:KT", "RD", "무료",
"W:", "III", "WIII", "DW", "PWI", "이비번", "와이파이비번", "파이비번",
"SSWOR", "WIFI비밀번호", "*WIFI", "F/W:", "ACCESS", "CODE", "Passw", "rd:", "ID/PASSWORD", "P/W", "1D",
"1층WIFI", "2층WIFI", "3층WIFI", "WI+I", "네트워크명", "-WI-FI-", "WI-I", "I비번", "와이", "파이", "와이파이비번",
"PASSWO", "RD", "WIT1", "D)", "ID)", "PW)", "W)", "[WI-FI", "PW]", "IDI", "ID]", "WIFI-PASSWORD", "F/W:", "WI-F",
"P.", "P.W", "IFI", "비밀번", "P/W", "W1-F1", "W1-F1", "무선와이파이", "/PW", "이디", "II)", "와이", "파이",
"비일번호", "번호", "WIF", "PA", "-비번", "SWORD:", "PASSWO", "RD", "WIT", "와이파이비번:", "PB:", "PIPI", "PASSWO",
"PASSWOR", "WIFI명", "WIFI명:", "·FI", "WI·FI", "비밀번", "비밀번오", "WIFE", "I-", "PIII", "Wiri"]

key_list = key_list3_general + key_list3_receipt
seperater = [':','.','_',"-","<",">","ㅣ","L","I","/","(",")", "'", ""]

new_list = []
for key in key_list:
    for s in seperater:
        keytmp = key
        key = key + s
        new_list.append(key)
        key= keytmp
        key = s + key
        new_list.append(key)
        key = keytmp
        
new_list = list(set(new_list)) +  [':', '/']

# %%
new_list = sorted(new_list)
print(len(new_list))
print(new_list)
# Out:
# 5269
# ["'(WI-FI)", "'**", "'*WIFI", "'-FI", "'-FI:", "'-WI-FI-", "'-비번", "'/PW", "'1/D", "'1D", "'1F", "'1·2층", "'1층", "'1층,2층", "'1층WIFI", "'2F", "'2층", "'2층WIFI", "'3F", "'3층", "'3층WIFI", "'4F", "'4층", "'5G전용", "'<WI-FI>", "'ACCESS", "'AP:", "'B1층", "'CODE", "'D)", "'D:", "'DW", "'F/W:", "'FI", "'FI:", "'FI_", "'FI비밀번호", "'FREE", "'FW", "'Fㅣ", "'I'D:", "'I-", "'I-FI", "'I-FI:", "'ID", "'ID)", "'ID-", "'ID/PASSWORD", "'ID:", "'ID:KT", "'IDI", "'ID]", "'ID_", "'IF", "'IFI", "'IFI_", "'IFI비밀번호", "'II)", "'III", "'IP", "'I_", "'I비번", "'I아이디", "'KEY", "'NAME", "'NETWORK", "'OI] ", "'P.", "'P.W", "'P.W.:", "'P.\\", "'P/W", "'P/Ø", "'PA", "'PAS", "'PASS", "'PASS:", "'PASSWARD", "'PASSWO", "'PASSWOR", "'PASSWORD", "'PASSWORD]", "'PASSWORE", "'PB:", "'PIII", "'PIN", "'PIPI", "'PN:", "'POSS", "'POSSWORD", "'PW", "'PW)", "'PW-", "'PW:", "'PWI", "'PW]", "'PW_", "'Passw", "'RD", "'SSID", "'SSWOR", "'SSWORD", "'SWORD:", "'SWORD]", "'T1", "'W)", "'W1", "'W1-F1", "'W1F1", "'W1T1", "'W1TI", "'W:", "'WF", "'WI", "'WI+I", "'WI-", "'WI-F", "'WI-F1", "'WI-FI", "'WI-FI(ID)", "'WI-FI:", "'WI-FIZONE", "'WI-I", "'WIF", "'WIFE", "'WIFI", "'WIFI(와이", "'WIFI(와이파이)", "'WIFI-PASSWORD", "'WIFIID", "'WIFIPASSWORD", "'WIFI명", "'WIFI명:", "'WIFI비밀번호", "'WIFI아이디", "'WIFI아이디는", "'WIFT", "'WIII", "'WIP", "'WIPI", "'WIT", "'WIT1", "'WITI", "'WI·FI", "'WORD", "'WTFI", "'WTFT", "'Wiri", "'Wㅣ", "'ZONE", "'[WI-FI", "'[WIF", "'[와이파", "'[와이파이]", "'\\IFI", "'rd:", "'|비밀번호", "'·FI", "'★PASSWORD", "'★PASSWORD★", "'검색명칭", "'계정", "'네트워크", "'네트워크:", "'네트워크명", "'무료", "'무선", "'무선랜", "'무선랜명:", "'무선와이파이", "'무선인터넷", "'무선인터넷은", "'번호", "'비밀번", "'비밀번오", "'비밀번호", "'비밀번호는", "'비번", "'비일번호", "'아이디", "'와이", "'와이파", "'와이파이", "'와이파이P/W", "'와이파이명", "'와이파이비번", "'와이파이비번:", "'이디", "'이름", "'이비번", "'이파이", "'인터넷", "'파이", "'파이비번", "'패스워드", "'패스워드:", "'패스워트", '((WI-FI)', '(**', '(*WIFI', '(-FI', '(-FI:', '(-WI-FI-', '(-비번', '(/PW', '(1/D', '(1D', '(1F', '(1·2층', '(1층', '(1층,2층', '(1층WIFI', '(2F', '(2층', '(2층WIFI', '(3F', '(3층', '(3층WIFI', '(4F', '(4층', '(5G전용', '(<WI-FI>', '(ACCESS', '(AP:', '(B1층', '(CODE', '(D)', '(D:', '(DW', '(F/W:', '(FI', '(FI:', '(FI_', '(FI비밀번호', '(FREE', '(FW', '(Fㅣ', "(I'D:", '(I-', '(I-FI', '(I-FI:', '(ID', '(ID)', '(ID-', '(ID/PASSWORD', '(ID:', '(ID:KT', '(IDI', '(ID]', '(ID_', '(IF', '(IFI', '(IFI_', '(IFI비밀번호', '(II)', '(III', '(IP', '(I_', '(I비번', '(I아이디', '(KEY', '(NAME', '(NETWORK', '(OI] ', '(P.', '(P.W', '(P.W.:', '(P.\\', '(P/W', '(P/Ø', '(PA', '(PAS', '(PASS', '(PASS:', '(PASSWARD', '(PASSWO', '(PASSWOR', '(PASSWORD', '(PASSWORD]', '(PASSWORE', '(PB:', '(PIII', '(PIN', '(PIPI', '(PN:', '(POSS', '(POSSWORD', '(PW', '(PW)', '(PW-', '(PW:', '(PWI', '(PW]', '(PW_', '(Passw', '(RD', '(SSID', '(SSWOR', '(SSWORD', '(SWORD:', '(SWORD]', '(T1', '(W)', '(W1', '(W1-F1', '(W1F1', '(W1T1', '(W1TI', '(W:', '(WF', '(WI', '(WI+I', '(WI-', '(WI-F', '(WI-F1', '(WI-FI', '(WI-FI(ID)', '(WI-FI)', "(WI-FI)'", '(WI-FI)(', '(WI-FI))', '(WI-FI)-', '(WI-FI).', '(WI-FI)/', '(WI-FI):', '(WI-FI)<', '(WI-FI)>', '(WI-FI)I', '(WI-FI)L', '(WI-FI)_', '(WI-FI)ㅣ', '(WI-FI:', '(WI-FIZONE', '(WI-I', '(WIF', '(WIFE', '(WIFI', '(WIFI(와이', '(WIFI(와이파이)', '(WIFI-PASSWORD', '(WIFIID', '(WIFIPASSWORD', '(WIFI명', '(WIFI명:', '(WIFI비밀번호', '(WIFI아이디', '(WIFI아이디는', '(WIFT', '(WIII', '(WIP', '(WIPI', '(WIT', '(WIT1', '(WITI', '(WI·FI', '(WORD', '(WTFI', '(WTFT', '(Wiri', '(Wㅣ', '(ZONE', '([WI-FI', '([WIF', '([와이파', '([와이파이]', '(\\IFI', '(rd:', '(|비밀번호', '(·FI', '(★PASSWORD', '(★PASSWORD★', '(검색명칭', '(계정', '(네트워크', '(네트워크:', '(네트워크명', '(무료', '(무선', '(무선랜', '(무선랜명:', '(무선와이파이', '(무선인터넷', '(무선인터넷은', '(번호', '(비밀번', '(비밀번오', '(비밀번호', '(비밀번호는', '(비번', '(비일번호', '(아이디', '(와이', '(와이파', '(와이파이', '(와이파이P/W', '(와이파이명', '(와이파이비번', '(와이파이비번:', '(이디', '(이름', '(이비번', '(이파이', '(인터넷', '(파이', '(파이비번', '(패스워드', '(패스워드:', '(패스워트', ')(WI-FI)', ')**', ')*WIFI', ')-FI', ')-FI:', ')-WI-FI-', ')-비번', ')/PW', ')1/D', ')1D', ')1F', ')1·2층', ')1층', ')1층,2층', ')1층WIFI', ')2F', ')2층', ')2층WIFI', ')3F', ')3층', ')3층WIFI', ')4F', ')4층', ')5G전용', ') ...
